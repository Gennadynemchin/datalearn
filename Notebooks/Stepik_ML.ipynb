# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance=pd.read_csv('c:/Users/OCS/Documents/GitHub/ds/Datasets/StudentsPerformance.csv')

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.groupby('gender').aggregate({'writing score': 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance.iloc[0:3,0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
students_performance_with_names=students_performance.iloc[[1,3,4,5,7]]

# %%
students_performance_with_names.index=['John', 'Caesar', 'Conor', 'Jimmy', 'Crown']

# %%
students_performance_with_names
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# John    female        group C                some college      standard
# Caesar    male        group A          associate's degree  free/reduced
# Conor     male        group C                some college      standard
# Jimmy   female        group B          associate's degree      standard
# Crown     male        group B                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# John                 completed          69             90             88
# Caesar                    none          47             57             44
# Conor                     none          76             78             75
# Jimmy                     none          71             83             78
# Crown                     none          40             43             39

# %%
students_performance_with_names.loc[['John','Conor']]
# Out:
#        gender race/ethnicity parental level of education     lunch  \
# John   female        group C                some college  standard
# Conor    male        group C                some college  standard
#
#       test preparation course  math score  reading score  writing score
# John                completed          69             90             88
# Conor                    none          76             78             75

# %%
students_performance.iloc[:, 0]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
#         ...
# 970    female
# 971      male
# 972    female
# 973    female
# 974    female
# 975    female
# 976      male
# 977      male
# 978      male
# 979    female
# 980    female
# 981      male
# 982      male
# 983    female
# 984    female
# 985      male
# 986    female
# 987      male
# 988    female
# 989    female
# 990      male
# 991    female
# 992    female
# 993    female
# 994      male
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# ...

# %%
pd.Series([1,2,3], index=['a','b','c'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# 9    female             50
# 12   female             73
# 14   female             58
# 15   female             78
# 17   female             28
# 19   female             61
# 21   female             70
# 23   female             73
# 27   female             75
# 29   female             75
# 30   female             74
# 31   female             61
# 32   female             65
# 36   female             83
# 37   female             59
# 38   female             88
# 41   female             68
# 42   female             65
# 44   female             54
# 46   female             62
# 47   female             76
# 48   female             76
# 54   female             87
# 55   female             43
# 56   female             86
# ..      ...            ...
# 952  female             72
# 954  female             69
# ...

# %%
mean_writing_score=students_performance['writing score'].mean()

# %%
students_performance.loc[students_performance['writing score']>mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# ...

# %%
free_lunch=students_performance[(students_performance['lunch']=='free/reduced')]

# %%
free_lunch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 355 entries, 3 to 999
# Data columns (total 8 columns):
# gender                         355 non-null object
# race/ethnicity                 355 non-null object
# parental level of education    355 non-null object
# lunch                          355 non-null object
# test preparation course        355 non-null object
# math score                     355 non-null int64
# reading score                  355 non-null int64
# writing score                  355 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 25.0+ KB

# %%
355/1000 #вычисляем долю студентов с урезанным ланчем от общего количества учащихся
# Out:
# 0.355

# %%
standard_lunch=students_performance[students_performance['lunch']=='standard']

# %%
standard_lunch[['math score','reading score','writing score']].mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
free_lunch[['math score','reading score','writing score']].mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students_performance=students_performance.rename(columns={'parental level of education': 'parental_level_of_education',
                                     'test preparation course': 'test_preparation_course', 'math score': 'math_score',
                                    'reading score': 'reading_score', 'writing score': 'writing_score'})

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance_query=78

# %%
students_performance.query("math_score>@students_performance_query & gender=='female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 56   female        group E          associate's degree      standard
# 94   female        group B                some college      standard
# 102  female        group D          associate's degree      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 120  female        group C           bachelor's degree      standard
# 122  female        group C                some college      standard
# 125  female        group B                 high school      standard
# 164  female        group E             master's degree      standard
# 165  female        group C           bachelor's degree      standard
# 172  female        group D                some college      standard
# ...

# %%
score_columns=[x for x in list(students_performance) if 'score' in x]

# %%
students_performance.filter(like='score', axis=1)
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# 5            71             83             78
# 6            88             95             92
# 7            40             43             39
# 8            64             64             67
# 9            38             60             50
# 10           58             54             52
# 11           40             52             43
# 12           65             81             73
# 13           78             72             70
# 14           50             53             58
# 15           69             75             78
# 16           88             89             86
# 17           18             32             28
# 18           46             42             46
# ...

# %%
students_performance.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students_performance.groupby('gender').var()
# Out:
#         math_score  reading_score  writing_score
# gender
# female  239.985124     206.733938     220.369327
# male    206.102695     194.095945     199.200248

# %%
mean_scores=students_performance.groupby(['gender','race/ethnicity']).agg({'math_score':['mean', 'var'],'reading_score':['mean', 'var'],
                                            'writing_score':['mean', 'var'] }).rename(columns={
    'math_score':'mean_math_score','reading_score':'mean_reading_score','writing_score':'mean_writing_score'})

# %%
mean_scores
# Out:
#                       mean_math_score             mean_reading_score  \
#                                  mean         var               mean
# gender race/ethnicity
# female group A              58.527778  200.427778          69.000000
#        group B              61.403846  264.281927          71.076923
#        group C              62.033333  225.216760          71.944444
#        group D              65.248062  200.906734          74.046512
#        group E              70.811594  264.684569          75.840580
# male   group A              63.735849  210.851959          61.735849
#        group B              65.930233  200.418605          62.848837
#        group C              67.611511  198.529142          65.424460
#        group D              69.413534  171.456482          66.135338
#        group E              76.746479  204.449095          70.295775
#
#                                   mean_writing_score
# ...

# %%
mean_scores.loc[[('female', 'group A')]]
# Out:
#                       mean_math_score             mean_reading_score  \
#                                  mean         var               mean
# gender race/ethnicity
# female group A              58.527778  200.427778               69.0
#
#                                   mean_writing_score
#                               var               mean         var
# gender race/ethnicity
# female group A         220.457143          67.861111  214.694444

# %%
students_performance.sort_values(['gender', 'math_score'], ascending=False).groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
students_performance['total_score']=students_performance.math_score+ \
students_performance.reading_score+students_performance.writing_score

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
students_performance=students_performance.assign(total_score_log=np.log(students_performance.total_score))

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
data_heroes=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
data_heroes.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
data_heroes.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
data_heroes[['attack_type','primary_attr']].describe()
# Out:
#        attack_type primary_attr
# count          117          117
# unique           2            3
# top         Ranged          int
# freq            61           42

# %%
rostislav=pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
rostislav.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
rostislav.groupby('genus').agg({'sucrose':'mean','alanin':['min','mean','max'],'citrate':'mean','glucose':'mean','oleic_acid':'mean'})
# Out:
#               sucrose    alanin                       citrate   glucose  \
#                  mean       min      mean       max      mean      mean
# genus
# Ascophyllum  6.825467  0.875429  0.875429  0.875429  5.253527  3.414961
# Cladophora   4.008792  1.648450  3.997055  6.881024  5.288311  2.800276
# Fucus        4.355112  0.346431  3.566411  6.641303  4.214878  2.814803
# Palmaria     0.704580  3.176440  3.176440  3.176440  5.573905  3.242090
# Saccharina   4.183596  1.255251  3.524207  5.793163  3.346710  4.980594
#
#             oleic_acid
#                   mean
# genus
# Ascophyllum   2.432526
# Cladophora    2.263472
# Fucus         3.367647
# Palmaria      2.245538
# Saccharina    4.487252

# %%
rostislav.describe()
# Out:
#          sucrose     alanin    citrate    glucose  oleic_acid
# count  10.000000  10.000000  10.000000  10.000000   10.000000
# mean    4.098895   3.379068   4.603042   3.346347    3.054593
# std     2.271190   2.400529   2.084948   1.094572    1.739319
# min     0.704580   0.346431   1.071920   2.272724    0.304573
# 25%     2.589835   1.353551   3.563185   2.596385    2.292285
# 50%     3.569170   3.319066   5.413716   3.292899    2.678951
# 75%     6.476373   5.272747   5.786515   3.571159    3.965826
# max     6.825467   6.881024   6.940588   6.013219    6.405165

# %%
rostislav['group'].value_counts()
# Out:
# brown    6
# green    3
# red      1
# Name: group, dtype: int64

# %%
aaa=rostislav.groupby('group').agg({'sucrose':['min','max']})

# %%
aaa
# Out:
#         sucrose
#             min       max
# group
# brown  1.636122  6.825467
# green  2.452623  5.712284
# red    0.704580  0.704580

# %%
aaa=aaa.assign(min_max=aaa.sucrose['min']-aaa.sucrose['max'])

# %%
aaa
# Out:
#         sucrose             min_max
#             min       max
# group
# brown  1.636122  6.825467 -5.189345
# green  2.452623  5.712284 -3.259662
# red    0.704580  0.704580  0.000000

# %% [markdown]
# ## Визуализация данных

# %%
students_performance.math_score.hist()

# %%
students_performance.plot.scatter(x='math_score', y='reading_score')

# %%
ax = sns.lmplot(x='math_score', y='reading_score',hue='gender', fit_reg=True, data=students_performance)
ax.set_xlabels('Успеваемость по математике')
ax.set_ylabels('Успеваемость по чтению')

# %%
test_data_1 = pd.read_csv('c:/Users/OCS/Documents/GitHub/ds/Datasets/dataset_209770_6.txt', sep=' ')

# %%
test_data_1.head()
# Out:
#             x           y
# 0  300.891196  293.180699
# 1  310.393255  294.469758
# 2  395.801789  699.110937
# 3  381.881977  705.027194
# 4  293.662965  306.096706

# %%
test_data_1.plot.scatter(x='x',y='y')

# %%
data_of_heroes = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)

data_of_heroes['cnt'] = data_of_heroes.roles.str.count(',')+1

data_of_heroes.loc[:5, ['localized_name', 'cnt']]
# Out:
#    localized_name  cnt
# 0       Anti-Mage    3
# 1             Axe    4
# 2            Bane    4
# 3     Bloodseeker    5
# 4  Crystal Maiden    4
# 5     Drow Ranger    3

# %%
data_of_heroes['cnt'].value_counts()
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: cnt, dtype: int64

# %%
students_performance.groupby('gender', as_index=False).mean().rename(columns={'math_score':'mean_math_score',
                                                                             'reading_score':'mean_reading_score,',
                                                                             'writing_score':'mean_writing_score'}).index
# Out:
# Int64Index([0, 1], dtype='int64')
